# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
#from plotcm import plot_confusion_matrix

import pdb
import pickle as serializer

with open('dataset.txt', 'rb') as f:
    test = serializer.load(f)
torch.set_printoptions(linewidth=120)


print("hello")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-1eae10d8e6be> in <module>()
#      16 import pickle as serializer
#      17
# ---> 18 with open('dataset.txt', 'rb') as f:
#      19     test = serializer.load(f)
#      20 torch.set_printoptions(linewidth=120)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset.txt'
